# %% [markdown]
# <a href="https://colab.research.google.com/github/kartikkk2005/pytorch_project/blob/main/pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/google-research/vision_transformer.git
# Out:
# Cloning into 'vision_transformer'...
# remote: Enumerating objects: 1129, done.
# remote: Counting objects: 100% (541/541), done.
# remote: Compressing objects: 100% (155/155), done.
# remote: Total 1129 (delta 453), reused 387 (delta 386), pack-reused 588 (from 2)
# Receiving objects: 100% (1129/1129), 141.26 MiB | 26.83 MiB/s, done.
# Resolving deltas: 100% (648/648), done.

# %%
# %cd vision_transformer
# Out:
# /content/vision_transformer

# %%
# !pip install flax jax jaxlib tensorflow gradio pillow matplotlib

# %%
# !ls
# Out:
# CONTRIBUTING.md  mixer_figure.png  setup.py	   vit_jax
# LICENSE		 model_cards	   version.py	   vit_jax_augreg.ipynb
# lit.ipynb	 README.md	   vit_figure.png  vit_jax.ipynb

# %%
import gradio as gr
from PIL import Image
import torch
from transformers import ViTImageProcessor, ViTForImageClassification

# Load pretrained Vision Transformer model
model_name = "google/vit-base-patch16-224"

processor = ViTImageProcessor.from_pretrained(model_name)
model = ViTForImageClassification.from_pretrained(model_name)

def predict(image):
    # Process image
    inputs = processor(images=image, return_tensors="pt")

    # Model prediction
    with torch.no_grad():
        outputs = model(**inputs)

    logits = outputs.logits

    # Get predicted class
    predicted_class_idx = logits.argmax(-1).item()

    predicted_class = model.config.id2label[predicted_class_idx]

    # Confidence score
    probabilities = torch.nn.functional.softmax(logits, dim=-1)
    confidence = probabilities[0][predicted_class_idx].item()

    return f"Prediction: {predicted_class}\nConfidence: {confidence:.2%}"

# Gradio UI
demo = gr.Interface(
    fn=predict,
    inputs=gr.Image(type="pil"),
    outputs="text",
    title="Vision Transformer Image Classifier",
    description="Upload any image and AI will classify it",
    theme="soft"
)

demo.launch()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/160 [00:00<?, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/200 [00:00<?, ?it/s]
# ...
